# %% [markdown]
# 문제 1) ex2.csv 파일을 다음 조건에 맞게 불러오시오.
#
# 1. 칼럼 이름을 'one', 'two', 'three', 'four', 'content'로 지정
# 2. 'content' 칼럼을 색인으로 지정
# 3. 0번째 행부터 존재한다고 할 때, 1번째 행은 건너뛰기

# %% [markdown]
# 문제 2) 'exercise2.csv' 파일을 생성하고 데이터를 저장하여 다음과 같은 결과값이 출력되도록 하시오.
#
# - 클래스 사용하여 구분자 정의하기
#
#
# <결과>
#
# 월/화/수/목/금
#
# MON/TUE/WED/THU/FRI
#
# LUN/MAR/MER/JEU/VEN

# %% [markdown]
# 문제 3) 요일별 수업 정보를 담은 JSON 데이터를 생성하고, 그 중 월요일의 시간표를 데이터프레임 형태로 출력하시오. 이때 각 수업에는 과목명과 교시 정보가 포함되도록 하시오.
#
# ex)
# ![문제3 예시.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 문제 4)
#
# 1. 0행부터 50행, '1st'열부터 '3rd' 열로 이루어진, 임의의 실수 값이 담긴 데이터프레임을 생성하시오.
# 2. 'exercise4'라는 이름의 HDF5 파일을 만들어 이전의 데이터프레임을 저장한 후, 인덱스가 40번째 이상인 행들만을 출력하시오.
#
# ![문제4 예시.jpg](data:image/jpeg;base64,...)
